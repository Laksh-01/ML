# %%
from sklearn.datasets import make_classification 
import numpy as np 
import matplotlib.pyplot as plt
X ,y = make_classification(n_samples=100 , n_features=2 , n_informative=1,n_redundant=0 , n_classes=2 , n_clusters_per_class=1 , random_state=41 , hypercube=False , class_sep=10)

# %%
print(X.shape)
# Out:
# (100, 2)

# %%
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)

# %% [markdown]
# Doing once with Scikit Learn model

# %%
from sklearn.linear_model import LogisticRegression 
lor = LogisticRegression()
lor.fit(X,y)
# Out:
# LogisticRegression()

# %%
print("Coefficients " ,  lor.coef_)
print("Intercept " , lor.intercept_)
# Out:
# Coefficients  [[3.50144121 0.02773483]]
# Intercept  [2.25106636]

# %%
m1 = -(lor.coef_[0][0]/lor.coef_[0][1])
b1 = -(lor.intercept_/lor.coef_[0][1])

# %%
x_input = np.linspace(-3,3,100)
y_input = m1*x_input + b1

# %%
plt.plot(x_input , y_input)
plt.ylim(-3,2)
plt.scatter(X[: , 0],X[: , 1] , c=y, cmap = "winter")

# %%
def MyLogisticRegression(X,y):
    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.5 
    
    for i in range(5000):
        y_hat = sigmoid(np.dot(X , weights))
        weights = weights + lr*(np.dot((y - y_hat) , X) / X.shape[0])
    
    return weights[1:] , weights[0]

# %%
def sigmoid(z):
    return 1/(1 + np.exp(-z))

# %%
coef_,intercept_ = MyLogisticRegression(X,y)

# %%
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
x_input1 = np.linspace(-3,3,100)
y_input1 = m*x_input1 + b

# %%
plt.plot(x_input1 , y_input1 , color="red" , label="Gd")
plt.scatter(X[: , 0] , X[: , 1] , c=y , cmap = "winter")
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %% [markdown]
# Comparing both Approaches

# %%
plt.plot(x_input1 , y_input1 , color="red" , label="Gd")
plt.plot(x_input ,y_input , color="black" , label ="scikit")
plt.scatter(X[: , 0] , X[: , 1] , c=y , cmap = "winter")
plt.ylim(-3,2)
plt.legend()

# %% [markdown]
# Performance of This Model
